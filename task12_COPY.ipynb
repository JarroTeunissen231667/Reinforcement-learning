# %%
import time
import numpy as np
from ot2_env_wrapper import OT2Env

# PID Controller Class
class PIDController:
    def __init__(self, kp, ki, kd, setpoint):
        self.kp = kp
        self.ki = ki
        self.kd = kd
        self.setpoint = setpoint
        self.integral = 0
        self.previous_error = 0

    def compute(self, current_position, dt):
        error = self.setpoint - current_position
        self.integral += error * dt
        derivative = (error - self.previous_error) / dt if dt > 0 else 0
        output = self.kp * error + self.ki * self.integral + self.kd * derivative

        # Anti-windup: Dynamically limit the integral term
        max_integral = 0.5  # Further tightened for precision
        self.integral = max(min(self.integral, max_integral), -max_integral)

        self.previous_error = error
        return output

# Environment Wrapper with PID Integration
class OT2EnvWithPID(OT2Env):
    def __init__(self, render=False, max_steps=500):
        super(OT2EnvWithPID, self).__init__(render, max_steps)

        # Initialize PID controllers for X, Y, Z axes
        self.pid_x = PIDController(kp=3.0, ki=0.2, kd=0.2, setpoint=0.0)
        self.pid_y = PIDController(kp=3.0, ki=0.2, kd=0.2, setpoint=0.0)
        self.pid_z = PIDController(kp=3.5, ki=0.25, kd=0.25, setpoint=0.0)

        # Set a random goal position
        self.goal_position = np.array([
            np.random.uniform(-0.187, 0.253),
            np.random.uniform(-0.1705, 0.2195),
            np.random.uniform(0.1195, 0.2895)
        ], dtype=np.float32)

    def step(self, action):
        # Update PID setpoints with goal position
        self.pid_x.setpoint = self.goal_position[0]
        self.pid_y.setpoint = self.goal_position[1]
        self.pid_z.setpoint = self.goal_position[2]

        # Get current pipette position
        robot_id_key = f'robotId_{self.sim.robotIds[0]}'
        pipette_position = self.sim.get_states()[robot_id_key]['pipette_position']

        # Compute corrections using PID controllers
        dt = 0.005  # Further reduced time step for higher precision
        distance = np.linalg.norm(pipette_position - self.goal_position)

        # Dynamic gain adjustment based on distance
        scaling_factor = max(1.0, min(10.0, distance * 10))  # Scale between 1x and 10x
        self.pid_x.kp = 3.0 * scaling_factor
        self.pid_y.kp = 3.0 * scaling_factor
        self.pid_z.kp = 3.5 * scaling_factor

        correction_x = self.pid_x.compute(pipette_position[0], dt)
        correction_y = self.pid_y.compute(pipette_position[1], dt)
        correction_z = self.pid_z.compute(pipette_position[2], dt)

        # Combine corrections into action
        pid_action = [correction_x, correction_y, correction_z, action[-1]]  # Include drop action

        # Execute the action in the simulation
        observation, reward, terminated, truncated, info = super().step(pid_action)

        # Modify reward based on PID performance
        distance = np.linalg.norm(pipette_position - self.goal_position)
        reward = -distance  # Reward is negative distance to goal

        # Print current distance to goal in millimeters
        distance_mm = distance * 1000  # Convert meters to millimeters
        print(f"Step {self.steps}: Distance to Goal: {distance_mm:.3f} mm")

        # Termination condition: 1 mm threshold for accuracy
        termination_threshold = 0.001
        terminated = distance < termination_threshold

        # Early exit for non-convergence: stop if not reducing error
        if self.steps > 300 and distance_mm > 10:  # Error plateau
            terminated = True
            print("Terminating early due to non-convergence.")

        return observation, reward, terminated, truncated, info

# Simulation Function
if __name__ == "__main__":
    # Initialize environment with PID integration
    env = OT2EnvWithPID(render=False, max_steps=500)

    # Reset environment
    obs, _ = env.reset()

    # Simulate steps
    for step in range(500):
        # Example action: PID corrections
        action = [0, 0, 0, 0]  
        obs, reward, terminated, truncated, info = env.step(action)
        print(f"Step {step}: Reward = {reward:.4f}, Terminated = {terminated}")

        if terminated or truncated:
            break

    print("\nSimulation complete.")
    env.close()
# Out:
# Step 1: Distance to Goal: 161.737 mm
# Step 0: Reward = -0.1617, Terminated = False
# Step 2: Distance to Goal: 160.698 mm
# Step 1: Reward = -0.1607, Terminated = False
# Step 3: Distance to Goal: 159.067 mm
# Step 2: Reward = -0.1591, Terminated = False
# Step 4: Distance to Goal: 157.038 mm
# Step 3: Reward = -0.1570, Terminated = False
# Step 5: Distance to Goal: 154.372 mm
# Step 4: Reward = -0.1544, Terminated = False
# Step 6: Distance to Goal: 151.718 mm
# Step 5: Reward = -0.1517, Terminated = False
# Step 7: Distance to Goal: 149.330 mm
# Step 6: Reward = -0.1493, Terminated = False
# Step 8: Distance to Goal: 146.809 mm
# Step 7: Reward = -0.1468, Terminated = False
# Step 9: Distance to Goal: 144.510 mm
# Step 8: Reward = -0.1445, Terminated = False
# Step 10: Distance to Goal: 142.212 mm
# Step 9: Reward = -0.1422, Terminated = False
# Step 11: Distance to Goal: 137.193 mm
# Step 10: Reward = -0.1372, Terminated = False
# Step 12: Distance to Goal: 133.062 mm
# Step 11: Reward = -0.1331, Terminated = False
# Step 13: Distance to Goal: 129.602 mm
# Step 12: Reward = -0.1296, Terminated = False
# Step 14: Distance to Goal: 126.869 mm
# Step 13: Reward = -0.1269, Terminated = False
# Step 15: Distance to Goal: 124.343 mm
# Step 14: Reward = -0.1243, Terminated = False
# Step 16: Distance to Goal: 122.174 mm
# Step 15: Reward = -0.1222, Terminated = False
# Step 17: Distance to Goal: 120.107 mm
# Step 16: Reward = -0.1201, Terminated = False
# Step 18: Distance to Goal: 118.250 mm
# Step 17: Reward = -0.1183, Terminated = False
# Step 19: Distance to Goal: 116.571 mm
# Step 18: Reward = -0.1166, Terminated = False
# Step 20: Distance to Goal: 114.966 mm
# Step 19: Reward = -0.1150, Terminated = False
# Step 21: Distance to Goal: 113.409 mm
# Step 20: Reward = -0.1134, Terminated = False
# Step 22: Distance to Goal: 111.972 mm
# Step 21: Reward = -0.1120, Terminated = False
# Step 23: Distance to Goal: 110.593 mm
# Step 22: Reward = -0.1106, Terminated = False
# Step 24: Distance to Goal: 109.223 mm
# Step 23: Reward = -0.1092, Terminated = False
# Step 25: Distance to Goal: 107.971 mm
# Step 24: Reward = -0.1080, Terminated = False
# Step 26: Distance to Goal: 106.600 mm
# Step 25: Reward = -0.1066, Terminated = False
# Step 27: Distance to Goal: 105.480 mm
# Step 26: Reward = -0.1055, Terminated = False
# Step 28: Distance to Goal: 104.228 mm
# Step 27: Reward = -0.1042, Terminated = False
# Step 29: Distance to Goal: 103.072 mm
# Step 28: Reward = -0.1031, Terminated = False
# Step 30: Distance to Goal: 101.931 mm
# Step 29: Reward = -0.1019, Terminated = False
# Step 31: Distance to Goal: 100.775 mm
# Step 30: Reward = -0.1008, Terminated = False
# Step 32: Distance to Goal: 99.655 mm
# Step 31: Reward = -0.0997, Terminated = False
# Step 33: Distance to Goal: 98.596 mm
# Step 32: Reward = -0.0986, Terminated = False
# Step 34: Distance to Goal: 97.476 mm
# Step 33: Reward = -0.0975, Terminated = False
# Step 35: Distance to Goal: 96.417 mm
# Step 34: Reward = -0.0964, Terminated = False
# Step 36: Distance to Goal: 95.372 mm
# Step 35: Reward = -0.0954, Terminated = False
# Step 37: Distance to Goal: 94.348 mm
# Step 36: Reward = -0.0943, Terminated = False
# Step 38: Distance to Goal: 93.311 mm
# Step 37: Reward = -0.0933, Terminated = False
# Step 39: Distance to Goal: 92.266 mm
# Step 38: Reward = -0.0923, Terminated = False
# Step 40: Distance to Goal: 91.326 mm
# Step 39: Reward = -0.0913, Terminated = False
# Step 41: Distance to Goal: 90.281 mm
# Step 40: Reward = -0.0903, Terminated = False
# Step 42: Distance to Goal: 89.257 mm
# Step 41: Reward = -0.0893, Terminated = False
# Step 43: Distance to Goal: 88.316 mm
# Step 42: Reward = -0.0883, Terminated = False
# Step 44: Distance to Goal: 87.369 mm
# Step 43: Reward = -0.0874, Terminated = False
# Step 45: Distance to Goal: 86.345 mm
# Step 44: Reward = -0.0863, Terminated = False
# Step 46: Distance to Goal: 85.404 mm
# Step 45: Reward = -0.0854, Terminated = False
# Step 47: Distance to Goal: 84.477 mm
# Step 46: Reward = -0.0845, Terminated = False
# Step 48: Distance to Goal: 83.530 mm
# Step 47: Reward = -0.0835, Terminated = False
# Step 49: Distance to Goal: 82.720 mm
# Step 48: Reward = -0.0827, Terminated = False
# Step 50: Distance to Goal: 81.759 mm
# Step 49: Reward = -0.0818, Terminated = False
# Step 51: Distance to Goal: 80.832 mm
# Step 50: Reward = -0.0808, Terminated = False
# Step 52: Distance to Goal: 80.002 mm
# Step 51: Reward = -0.0800, Terminated = False
# Step 53: Distance to Goal: 79.075 mm
# Step 52: Reward = -0.0791, Terminated = False
# Step 54: Distance to Goal: 78.245 mm
# Step 53: Reward = -0.0782, Terminated = False
# Step 55: Distance to Goal: 77.304 mm
# Step 54: Reward = -0.0773, Terminated = False
# Step 56: Distance to Goal: 76.474 mm
# Step 55: Reward = -0.0765, Terminated = False
# Step 57: Distance to Goal: 75.644 mm
# Step 56: Reward = -0.0756, Terminated = False
# Step 58: Distance to Goal: 74.814 mm
# Step 57: Reward = -0.0748, Terminated = False
# Step 59: Distance to Goal: 73.984 mm
# Step 58: Reward = -0.0740, Terminated = False
# Step 60: Distance to Goal: 73.155 mm
# Step 59: Reward = -0.0732, Terminated = False
# Step 61: Distance to Goal: 72.325 mm
# Step 60: Reward = -0.0723, Terminated = False
# Step 62: Distance to Goal: 71.598 mm
# Step 61: Reward = -0.0716, Terminated = False
# Step 63: Distance to Goal: 70.782 mm
# Step 62: Reward = -0.0708, Terminated = False
# Step 64: Distance to Goal: 69.938 mm
# Step 63: Reward = -0.0699, Terminated = False
# Step 65: Distance to Goal: 69.205 mm
# Step 64: Reward = -0.0692, Terminated = False
# Step 66: Distance to Goal: 68.375 mm
# Step 65: Reward = -0.0684, Terminated = False
# Step 67: Distance to Goal: 67.663 mm
# Step 66: Reward = -0.0677, Terminated = False
# Step 68: Distance to Goal: 66.930 mm
# Step 67: Reward = -0.0669, Terminated = False
# Step 69: Distance to Goal: 66.197 mm
# Step 68: Reward = -0.0662, Terminated = False
# Step 70: Distance to Goal: 65.387 mm
# Step 69: Reward = -0.0654, Terminated = False
# Step 71: Distance to Goal: 64.751 mm
# Step 70: Reward = -0.0648, Terminated = False
# Step 72: Distance to Goal: 63.921 mm
# Step 71: Reward = -0.0639, Terminated = False
# Step 73: Distance to Goal: 63.306 mm
# Step 72: Reward = -0.0633, Terminated = False
# Step 74: Distance to Goal: 62.573 mm
# Step 73: Reward = -0.0626, Terminated = False
# Step 75: Distance to Goal: 61.840 mm
# Step 74: Reward = -0.0618, Terminated = False
# Step 76: Distance to Goal: 61.127 mm
# Step 75: Reward = -0.0611, Terminated = False
# Step 77: Distance to Goal: 60.505 mm
# Step 76: Reward = -0.0605, Terminated = False
# Step 78: Distance to Goal: 59.779 mm
# Step 77: Reward = -0.0598, Terminated = False
# Step 79: Distance to Goal: 59.157 mm
# Step 78: Reward = -0.0592, Terminated = False
# Step 80: Distance to Goal: 58.444 mm
# Step 79: Reward = -0.0584, Terminated = False
# Step 81: Distance to Goal: 57.808 mm
# Step 80: Reward = -0.0578, Terminated = False
# Step 82: Distance to Goal: 57.192 mm
# Step 81: Reward = -0.0572, Terminated = False
# Step 83: Distance to Goal: 56.557 mm
# Step 82: Reward = -0.0566, Terminated = False
# Step 84: Distance to Goal: 55.844 mm
# Step 83: Reward = -0.0558, Terminated = False
# Step 85: Distance to Goal: 55.228 mm
# Step 84: Reward = -0.0552, Terminated = False
# Step 86: Distance to Goal: 54.606 mm
# Step 85: Reward = -0.0546, Terminated = False
# Step 87: Distance to Goal: 54.087 mm
# Step 86: Reward = -0.0541, Terminated = False
# Step 88: Distance to Goal: 53.355 mm
# Step 87: Reward = -0.0534, Terminated = False
# Step 89: Distance to Goal: 52.836 mm
# Step 88: Reward = -0.0528, Terminated = False
# Step 90: Distance to Goal: 52.220 mm
# Step 89: Reward = -0.0522, Terminated = False
# Step 91: Distance to Goal: 51.585 mm
# Step 90: Reward = -0.0516, Terminated = False
# Step 92: Distance to Goal: 51.080 mm
# Step 91: Reward = -0.0511, Terminated = False
# Step 93: Distance to Goal: 50.464 mm
# Step 92: Reward = -0.0505, Terminated = False
# Step 94: Distance to Goal: 49.848 mm
# Step 93: Reward = -0.0498, Terminated = False
# Step 95: Distance to Goal: 49.310 mm
# Step 94: Reward = -0.0493, Terminated = False
# Step 96: Distance to Goal: 48.791 mm
# Step 95: Reward = -0.0488, Terminated = False
# Step 97: Distance to Goal: 48.189 mm
# Step 96: Reward = -0.0482, Terminated = False
# Step 98: Distance to Goal: 47.670 mm
# Step 97: Reward = -0.0477, Terminated = False
# Step 99: Distance to Goal: 47.132 mm
# Step 98: Reward = -0.0471, Terminated = False
# Step 100: Distance to Goal: 46.530 mm
# Step 99: Reward = -0.0465, Terminated = False
# Step 101: Distance to Goal: 46.011 mm
# Step 100: Reward = -0.0460, Terminated = False
# Step 102: Distance to Goal: 45.492 mm
# Step 101: Reward = -0.0455, Terminated = False
# Step 103: Distance to Goal: 44.973 mm
# Step 102: Reward = -0.0450, Terminated = False
# Step 104: Distance to Goal: 44.468 mm
# Step 103: Reward = -0.0445, Terminated = False
# Step 105: Distance to Goal: 43.949 mm
# Step 104: Reward = -0.0439, Terminated = False
# Step 106: Distance to Goal: 43.509 mm
# Step 105: Reward = -0.0435, Terminated = False
# Step 107: Distance to Goal: 43.023 mm
# Step 106: Reward = -0.0430, Terminated = False
# Step 108: Distance to Goal: 42.485 mm
# Step 107: Reward = -0.0425, Terminated = False
# Step 109: Distance to Goal: 41.966 mm
# Step 108: Reward = -0.0420, Terminated = False
# Step 110: Distance to Goal: 41.461 mm
# Step 109: Reward = -0.0415, Terminated = False
# Step 111: Distance to Goal: 41.040 mm
# Step 110: Reward = -0.0410, Terminated = False
# Step 112: Distance to Goal: 40.521 mm
# Step 111: Reward = -0.0405, Terminated = False
# Step 113: Distance to Goal: 40.113 mm
# Step 112: Reward = -0.0401, Terminated = False
# Step 114: Distance to Goal: 39.594 mm
# Step 113: Reward = -0.0396, Terminated = False
# Step 115: Distance to Goal: 39.173 mm
# Step 114: Reward = -0.0392, Terminated = False
# Step 116: Distance to Goal: 38.668 mm
# Step 115: Reward = -0.0387, Terminated = False
# Step 117: Distance to Goal: 38.246 mm
# Step 116: Reward = -0.0382, Terminated = False
# Step 118: Distance to Goal: 37.825 mm
# Step 117: Reward = -0.0378, Terminated = False
# Step 119: Distance to Goal: 37.320 mm
# Step 118: Reward = -0.0373, Terminated = False
# Step 120: Distance to Goal: 36.917 mm
# Step 119: Reward = -0.0369, Terminated = False
# Step 121: Distance to Goal: 36.491 mm
# Step 120: Reward = -0.0365, Terminated = False
# Step 122: Distance to Goal: 36.088 mm
# Step 121: Reward = -0.0361, Terminated = False
# Step 123: Distance to Goal: 35.680 mm
# Step 122: Reward = -0.0357, Terminated = False
# Step 124: Distance to Goal: 35.258 mm
# Step 123: Reward = -0.0353, Terminated = False
# Step 125: Distance to Goal: 34.837 mm
# Step 124: Reward = -0.0348, Terminated = False
# Step 126: Distance to Goal: 34.429 mm
# Step 125: Reward = -0.0344, Terminated = False
# Step 127: Distance to Goal: 34.008 mm
# Step 126: Reward = -0.0340, Terminated = False
# Step 128: Distance to Goal: 33.600 mm
# Step 127: Reward = -0.0336, Terminated = False
# Step 129: Distance to Goal: 33.197 mm
# Step 128: Reward = -0.0332, Terminated = False
# Step 130: Distance to Goal: 32.789 mm
# Step 129: Reward = -0.0328, Terminated = False
# Step 131: Distance to Goal: 32.465 mm
# Step 130: Reward = -0.0325, Terminated = False
# Step 132: Distance to Goal: 32.058 mm
# Step 131: Reward = -0.0321, Terminated = False
# Step 133: Distance to Goal: 31.636 mm
# Step 132: Reward = -0.0316, Terminated = False
# Step 134: Distance to Goal: 31.344 mm
# Step 133: Reward = -0.0313, Terminated = False
# Step 135: Distance to Goal: 30.923 mm
# Step 134: Reward = -0.0309, Terminated = False
# Step 136: Distance to Goal: 30.515 mm
# Step 135: Reward = -0.0305, Terminated = False
# Step 137: Distance to Goal: 30.191 mm
# Step 136: Reward = -0.0302, Terminated = False
# Step 138: Distance to Goal: 29.784 mm
# Step 137: Reward = -0.0298, Terminated = False
# Step 139: Distance to Goal: 29.478 mm
# Step 138: Reward = -0.0295, Terminated = False
# Step 140: Distance to Goal: 29.168 mm
# Step 139: Reward = -0.0292, Terminated = False
# Step 141: Distance to Goal: 28.746 mm
# Step 140: Reward = -0.0287, Terminated = False
# Step 142: Distance to Goal: 28.454 mm
# Step 141: Reward = -0.0285, Terminated = False
# Step 143: Distance to Goal: 28.033 mm
# Step 142: Reward = -0.0280, Terminated = False
# Step 144: Distance to Goal: 27.723 mm
# Step 143: Reward = -0.0277, Terminated = False
# Step 145: Distance to Goal: 27.399 mm
# Step 144: Reward = -0.0274, Terminated = False
# Step 146: Distance to Goal: 27.107 mm
# Step 145: Reward = -0.0271, Terminated = False
# Step 147: Distance to Goal: 26.783 mm
# Step 146: Reward = -0.0268, Terminated = False
# Step 148: Distance to Goal: 26.375 mm
# Step 147: Reward = -0.0264, Terminated = False
# Step 149: Distance to Goal: 26.069 mm
# Step 148: Reward = -0.0261, Terminated = False
# Step 150: Distance to Goal: 25.759 mm
# Step 149: Reward = -0.0258, Terminated = False
# Step 151: Distance to Goal: 25.449 mm
# Step 150: Reward = -0.0254, Terminated = False
# Step 152: Distance to Goal: 25.143 mm
# Step 151: Reward = -0.0251, Terminated = False
# Step 153: Distance to Goal: 24.833 mm
# Step 152: Reward = -0.0248, Terminated = False
# Step 154: Distance to Goal: 24.509 mm
# Step 153: Reward = -0.0245, Terminated = False
# Step 155: Distance to Goal: 24.217 mm
# Step 154: Reward = -0.0242, Terminated = False
# Step 156: Distance to Goal: 23.893 mm
# Step 155: Reward = -0.0239, Terminated = False
# Step 157: Distance to Goal: 23.698 mm
# Step 156: Reward = -0.0237, Terminated = False
# Step 158: Distance to Goal: 23.388 mm
# Step 157: Reward = -0.0234, Terminated = False
# Step 159: Distance to Goal: 23.065 mm
# Step 158: Reward = -0.0231, Terminated = False
# Step 160: Distance to Goal: 22.772 mm
# Step 159: Reward = -0.0228, Terminated = False
# Step 161: Distance to Goal: 22.449 mm
# Step 160: Reward = -0.0224, Terminated = False
# Step 162: Distance to Goal: 22.253 mm
# Step 161: Reward = -0.0223, Terminated = False
# Step 163: Distance to Goal: 21.944 mm
# Step 162: Reward = -0.0219, Terminated = False
# Step 164: Distance to Goal: 21.637 mm
# Step 163: Reward = -0.0216, Terminated = False
# Step 165: Distance to Goal: 21.425 mm
# Step 164: Reward = -0.0214, Terminated = False
# Step 166: Distance to Goal: 21.132 mm
# Step 165: Reward = -0.0211, Terminated = False
# Step 167: Distance to Goal: 20.809 mm
# Step 166: Reward = -0.0208, Terminated = False
# Step 168: Distance to Goal: 20.597 mm
# Step 167: Reward = -0.0206, Terminated = False
# Step 169: Distance to Goal: 20.304 mm
# Step 168: Reward = -0.0203, Terminated = False
# Step 170: Distance to Goal: 20.079 mm
# Step 169: Reward = -0.0201, Terminated = False
# Step 171: Distance to Goal: 19.786 mm
# Step 170: Reward = -0.0198, Terminated = False
# Step 172: Distance to Goal: 19.560 mm
# Step 171: Reward = -0.0196, Terminated = False
# Step 173: Distance to Goal: 19.365 mm
# Step 172: Reward = -0.0194, Terminated = False
# Step 174: Distance to Goal: 19.055 mm
# Step 173: Reward = -0.0191, Terminated = False
# Step 175: Distance to Goal: 18.846 mm
# Step 174: Reward = -0.0188, Terminated = False
# Step 176: Distance to Goal: 18.537 mm
# Step 175: Reward = -0.0185, Terminated = False
# Step 177: Distance to Goal: 18.341 mm
# Step 176: Reward = -0.0183, Terminated = False
# Step 178: Distance to Goal: 18.116 mm
# Step 177: Reward = -0.0181, Terminated = False
# Step 179: Distance to Goal: 17.920 mm
# Step 178: Reward = -0.0179, Terminated = False
# Step 180: Distance to Goal: 17.627 mm
# Step 179: Reward = -0.0176, Terminated = False
# Step 181: Distance to Goal: 17.416 mm
# Step 180: Reward = -0.0174, Terminated = False
# Step 182: Distance to Goal: 17.206 mm
# Step 181: Reward = -0.0172, Terminated = False
# Step 183: Distance to Goal: 16.995 mm
# Step 182: Reward = -0.0170, Terminated = False
# Step 184: Distance to Goal: 16.702 mm
# Step 183: Reward = -0.0167, Terminated = False
# Step 185: Distance to Goal: 16.574 mm
# Step 184: Reward = -0.0166, Terminated = False
# Step 186: Distance to Goal: 16.281 mm
# Step 185: Reward = -0.0163, Terminated = False
# Step 187: Distance to Goal: 16.070 mm
# Step 186: Reward = -0.0161, Terminated = False
# Step 188: Distance to Goal: 15.860 mm
# Step 187: Reward = -0.0159, Terminated = False
# Step 189: Distance to Goal: 15.665 mm
# Step 188: Reward = -0.0157, Terminated = False
# Step 190: Distance to Goal: 15.454 mm
# Step 189: Reward = -0.0155, Terminated = False
# Step 191: Distance to Goal: 15.258 mm
# Step 190: Reward = -0.0153, Terminated = False
# Step 192: Distance to Goal: 15.033 mm
# Step 191: Reward = -0.0150, Terminated = False
# Step 193: Distance to Goal: 14.837 mm
# Step 192: Reward = -0.0148, Terminated = False
# Step 194: Distance to Goal: 14.642 mm
# Step 193: Reward = -0.0146, Terminated = False
# Step 195: Distance to Goal: 14.417 mm
# Step 194: Reward = -0.0144, Terminated = False
# Step 196: Distance to Goal: 14.221 mm
# Step 195: Reward = -0.0142, Terminated = False
# Step 197: Distance to Goal: 14.123 mm
# Step 196: Reward = -0.0141, Terminated = False
# Step 198: Distance to Goal: 13.912 mm
# Step 197: Reward = -0.0139, Terminated = False
# Step 199: Distance to Goal: 13.703 mm
# Step 198: Reward = -0.0137, Terminated = False
# Step 200: Distance to Goal: 13.492 mm
# Step 199: Reward = -0.0135, Terminated = False
# Step 201: Distance to Goal: 13.296 mm
# Step 200: Reward = -0.0133, Terminated = False
# Step 202: Distance to Goal: 13.101 mm
# Step 201: Reward = -0.0131, Terminated = False
# Step 203: Distance to Goal: 12.974 mm
# Step 202: Reward = -0.0130, Terminated = False
# Step 204: Distance to Goal: 12.778 mm
# Step 203: Reward = -0.0128, Terminated = False
# Step 205: Distance to Goal: 12.582 mm
# Step 204: Reward = -0.0126, Terminated = False
# Step 206: Distance to Goal: 12.372 mm
# Step 205: Reward = -0.0124, Terminated = False
# Step 207: Distance to Goal: 12.260 mm
# Step 206: Reward = -0.0123, Terminated = False
# Step 208: Distance to Goal: 12.064 mm
# Step 207: Reward = -0.0121, Terminated = False
# Step 209: Distance to Goal: 11.854 mm
# Step 208: Reward = -0.0119, Terminated = False
# Step 210: Distance to Goal: 11.756 mm
# Step 209: Reward = -0.0118, Terminated = False
# Step 211: Distance to Goal: 11.546 mm
# Step 210: Reward = -0.0115, Terminated = False
# Step 212: Distance to Goal: 11.335 mm
# Step 211: Reward = -0.0113, Terminated = False
# Step 213: Distance to Goal: 11.237 mm
# Step 212: Reward = -0.0112, Terminated = False
# Step 214: Distance to Goal: 11.041 mm
# Step 213: Reward = -0.0110, Terminated = False
# Step 215: Distance to Goal: 10.930 mm
# Step 214: Reward = -0.0109, Terminated = False
# Step 216: Distance to Goal: 10.719 mm
# Step 215: Reward = -0.0107, Terminated = False
# Step 217: Distance to Goal: 10.621 mm
# Step 216: Reward = -0.0106, Terminated = False
# Step 218: Distance to Goal: 10.425 mm
# Step 217: Reward = -0.0104, Terminated = False
# Step 219: Distance to Goal: 10.314 mm
# Step 218: Reward = -0.0103, Terminated = False
# Step 220: Distance to Goal: 10.117 mm
# Step 219: Reward = -0.0101, Terminated = False
# Step 221: Distance to Goal: 10.005 mm
# Step 220: Reward = -0.0100, Terminated = False
# Step 222: Distance to Goal: 9.796 mm
# Step 221: Reward = -0.0098, Terminated = False
# Step 223: Distance to Goal: 9.697 mm
# Step 222: Reward = -0.0097, Terminated = False
# Step 224: Distance to Goal: 9.501 mm
# Step 223: Reward = -0.0095, Terminated = False
# Step 225: Distance to Goal: 9.389 mm
# Step 224: Reward = -0.0094, Terminated = False
# Step 226: Distance to Goal: 9.278 mm
# Step 225: Reward = -0.0093, Terminated = False
# Step 227: Distance to Goal: 9.082 mm
# Step 226: Reward = -0.0091, Terminated = False
# Step 228: Distance to Goal: 8.983 mm
# Step 227: Reward = -0.0090, Terminated = False
# Step 229: Distance to Goal: 8.885 mm
# Step 228: Reward = -0.0089, Terminated = False
# Step 230: Distance to Goal: 8.676 mm
# Step 229: Reward = -0.0087, Terminated = False
# Step 231: Distance to Goal: 8.564 mm
# Step 230: Reward = -0.0086, Terminated = False
# Step 232: Distance to Goal: 8.466 mm
# Step 231: Reward = -0.0085, Terminated = False
# Step 233: Distance to Goal: 8.269 mm
# Step 232: Reward = -0.0083, Terminated = False
# Step 234: Distance to Goal: 8.159 mm
# Step 233: Reward = -0.0082, Terminated = False
# Step 235: Distance to Goal: 8.060 mm
# Step 234: Reward = -0.0081, Terminated = False
# Step 236: Distance to Goal: 7.850 mm
# Step 235: Reward = -0.0078, Terminated = False
# Step 237: Distance to Goal: 7.752 mm
# Step 236: Reward = -0.0078, Terminated = False
# Step 238: Distance to Goal: 7.641 mm
# Step 237: Reward = -0.0076, Terminated = False
# Step 239: Distance to Goal: 7.543 mm
# Step 238: Reward = -0.0075, Terminated = False
# Step 240: Distance to Goal: 7.445 mm
# Step 239: Reward = -0.0074, Terminated = False
# Step 241: Distance to Goal: 7.248 mm
# Step 240: Reward = -0.0072, Terminated = False
# Step 242: Distance to Goal: 7.124 mm
# Step 241: Reward = -0.0071, Terminated = False
# Step 243: Distance to Goal: 7.026 mm
# Step 242: Reward = -0.0070, Terminated = False
# Step 244: Distance to Goal: 6.927 mm
# Step 243: Reward = -0.0069, Terminated = False
# Step 245: Distance to Goal: 6.829 mm
# Step 244: Reward = -0.0068, Terminated = False
# Step 246: Distance to Goal: 6.731 mm
# Step 245: Reward = -0.0067, Terminated = False
# Step 247: Distance to Goal: 6.622 mm
# Step 246: Reward = -0.0066, Terminated = False
# Step 248: Distance to Goal: 6.411 mm
# Step 247: Reward = -0.0064, Terminated = False
# Step 249: Distance to Goal: 6.312 mm
# Step 248: Reward = -0.0063, Terminated = False
# Step 250: Distance to Goal: 6.214 mm
# Step 249: Reward = -0.0062, Terminated = False
# Step 251: Distance to Goal: 6.115 mm
# Step 250: Reward = -0.0061, Terminated = False
# Step 252: Distance to Goal: 6.007 mm
# Step 251: Reward = -0.0060, Terminated = False
# Step 253: Distance to Goal: 5.908 mm
# Step 252: Reward = -0.0059, Terminated = False
# Step 254: Distance to Goal: 5.810 mm
# Step 253: Reward = -0.0058, Terminated = False
# Step 255: Distance to Goal: 5.697 mm
# Step 254: Reward = -0.0057, Terminated = False
# Step 256: Distance to Goal: 5.598 mm
# Step 255: Reward = -0.0056, Terminated = False
# Step 257: Distance to Goal: 5.490 mm
# Step 256: Reward = -0.0055, Terminated = False
# Step 258: Distance to Goal: 5.392 mm
# Step 257: Reward = -0.0054, Terminated = False
# Step 259: Distance to Goal: 5.293 mm
# Step 258: Reward = -0.0053, Terminated = False
# Step 260: Distance to Goal: 5.195 mm
# Step 259: Reward = -0.0052, Terminated = False
# Step 261: Distance to Goal: 5.096 mm
# Step 260: Reward = -0.0051, Terminated = False
# Step 262: Distance to Goal: 4.984 mm
# Step 261: Reward = -0.0050, Terminated = False
# Step 263: Distance to Goal: 4.876 mm
# Step 262: Reward = -0.0049, Terminated = False
# Step 264: Distance to Goal: 4.778 mm
# Step 263: Reward = -0.0048, Terminated = False
# Step 265: Distance to Goal: 4.778 mm
# Step 264: Reward = -0.0048, Terminated = False
# Step 266: Distance to Goal: 4.580 mm
# Step 265: Reward = -0.0046, Terminated = False
# Step 267: Distance to Goal: 4.580 mm
# Step 266: Reward = -0.0046, Terminated = False
# Step 268: Distance to Goal: 4.482 mm
# Step 267: Reward = -0.0045, Terminated = False
# Step 269: Distance to Goal: 4.376 mm
# Step 268: Reward = -0.0044, Terminated = False
# Step 270: Distance to Goal: 4.263 mm
# Step 269: Reward = -0.0043, Terminated = False
# Step 271: Distance to Goal: 4.164 mm
# Step 270: Reward = -0.0042, Terminated = False
# Step 272: Distance to Goal: 4.065 mm
# Step 271: Reward = -0.0041, Terminated = False
# Step 273: Distance to Goal: 3.966 mm
# Step 272: Reward = -0.0040, Terminated = False
# Step 274: Distance to Goal: 3.966 mm
# Step 273: Reward = -0.0040, Terminated = False
# Step 275: Distance to Goal: 3.868 mm
# Step 274: Reward = -0.0039, Terminated = False
# Step 276: Distance to Goal: 3.763 mm
# Step 275: Reward = -0.0038, Terminated = False
# Step 277: Distance to Goal: 3.664 mm
# Step 276: Reward = -0.0037, Terminated = False
# Step 278: Distance to Goal: 3.551 mm
# Step 277: Reward = -0.0036, Terminated = False
# Step 279: Distance to Goal: 3.566 mm
# Step 278: Reward = -0.0036, Terminated = False
# Step 280: Distance to Goal: 3.452 mm
# Step 279: Reward = -0.0035, Terminated = False
# Step 281: Distance to Goal: 3.353 mm
# Step 280: Reward = -0.0034, Terminated = False
# Step 282: Distance to Goal: 3.254 mm
# Step 281: Reward = -0.0033, Terminated = False
# Step 283: Distance to Goal: 3.152 mm
# Step 282: Reward = -0.0032, Terminated = False
# Step 284: Distance to Goal: 3.152 mm
# Step 283: Reward = -0.0032, Terminated = False
# Step 285: Distance to Goal: 3.053 mm
# Step 284: Reward = -0.0031, Terminated = False
# Step 286: Distance to Goal: 2.954 mm
# Step 285: Reward = -0.0030, Terminated = False
# Step 287: Distance to Goal: 2.954 mm
# Step 286: Reward = -0.0030, Terminated = False
# Step 288: Distance to Goal: 2.841 mm
# Step 287: Reward = -0.0028, Terminated = False
# Step 289: Distance to Goal: 2.742 mm
# Step 288: Reward = -0.0027, Terminated = False
# Step 290: Distance to Goal: 2.642 mm
# Step 289: Reward = -0.0026, Terminated = False
# Step 291: Distance to Goal: 2.643 mm
# Step 290: Reward = -0.0026, Terminated = False
# Step 292: Distance to Goal: 2.543 mm
# Step 291: Reward = -0.0025, Terminated = False
# Step 293: Distance to Goal: 2.444 mm
# Step 292: Reward = -0.0024, Terminated = False
# Step 294: Distance to Goal: 2.444 mm
# Step 293: Reward = -0.0024, Terminated = False
# Step 295: Distance to Goal: 2.345 mm
# Step 294: Reward = -0.0023, Terminated = False
# Step 296: Distance to Goal: 2.247 mm
# Step 295: Reward = -0.0022, Terminated = False
# Step 297: Distance to Goal: 2.247 mm
# Step 296: Reward = -0.0022, Terminated = False
# Step 298: Distance to Goal: 2.133 mm
# Step 297: Reward = -0.0021, Terminated = False
# Step 299: Distance to Goal: 2.053 mm
# Step 298: Reward = -0.0021, Terminated = False
# Step 300: Distance to Goal: 2.038 mm
# Step 299: Reward = -0.0020, Terminated = False
# Step 301: Distance to Goal: 1.939 mm
# Step 300: Reward = -0.0019, Terminated = False
# Step 302: Distance to Goal: 1.840 mm
# Step 301: Reward = -0.0018, Terminated = False
# Step 303: Distance to Goal: 1.840 mm
# Step 302: Reward = -0.0018, Terminated = False
# Step 304: Distance to Goal: 1.742 mm
# Step 303: Reward = -0.0017, Terminated = False
# Step 305: Distance to Goal: 1.742 mm
# Step 304: Reward = -0.0017, Terminated = False
# Step 306: Distance to Goal: 1.643 mm
# Step 305: Reward = -0.0016, Terminated = False
# Step 307: Distance to Goal: 1.545 mm
# Step 306: Reward = -0.0015, Terminated = False
# Step 308: Distance to Goal: 1.557 mm
# Step 307: Reward = -0.0016, Terminated = False
# Step 309: Distance to Goal: 1.447 mm
# Step 308: Reward = -0.0014, Terminated = False
# Step 310: Distance to Goal: 1.444 mm
# Step 309: Reward = -0.0014, Terminated = False
# Step 311: Distance to Goal: 1.346 mm
# Step 310: Reward = -0.0013, Terminated = False
# Step 312: Distance to Goal: 1.346 mm
# Step 311: Reward = -0.0013, Terminated = False
# Step 313: Distance to Goal: 1.249 mm
# Step 312: Reward = -0.0012, Terminated = False
# Step 314: Distance to Goal: 1.152 mm
# Step 313: Reward = -0.0012, Terminated = False
# Step 315: Distance to Goal: 1.152 mm
# Step 314: Reward = -0.0012, Terminated = False
# Step 316: Distance to Goal: 1.055 mm
# Step 315: Reward = -0.0011, Terminated = False
# Step 317: Distance to Goal: 1.055 mm
# Step 316: Reward = -0.0011, Terminated = False
# Step 318: Distance to Goal: 0.959 mm
# Step 317: Reward = -0.0010, Terminated = True
#
# Simulation complete.
