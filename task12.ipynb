# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
from sim_class import Simulation


class PIDController:
    def __init__(self, Kp, Ki, Kd, setpoint=0):
        """
        PID controller for a single axis.
        """
        self.Kp = Kp
        self.Ki = Ki
        self.Kd = Kd
        self.setpoint = setpoint
        self.integral = 0
        self.previous_error = 0

    def update(self, current_value):
        """
        Calculate the control signal based on the current value.
        """
        error = self.setpoint - current_value
        self.integral += error
        derivative = error - self.previous_error
        self.previous_error = error
        return self.Kp * error + self.Ki * self.integral + self.Kd * derivative


class OT2Env(gym.Env):
    def __init__(self, render=False, max_steps=10000):
        super(OT2Env, self).__init__()
        self.render_enabled = render  # Use render_enabled to track rendering
        self.max_steps = max_steps

        # Create the simulation environment
        self.sim = Simulation(num_agents=1, render=self.render_enabled)

        # Define action and observation spaces
        self.action_space = spaces.Box(low=np.array([-1, -1, -1, 0]), high=np.array([1, 1, 1, 1]), shape=(4,), dtype=np.float32)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(6,), dtype=np.float32)

        # PID Controllers for X, Y, Z axes
        self.pid_x = PIDController(Kp=1.0, Ki=0.1, Kd=0.01, setpoint=0.0)
        self.pid_y = PIDController(Kp=1.0, Ki=0.1, Kd=0.01, setpoint=0.0)
        self.pid_z = PIDController(Kp=1.0, Ki=0.1, Kd=0.01, setpoint=0.0)

        # Track steps and goal position
        self.steps = 0
        self.goal_position = None

    def reset(self, seed=None):
        if seed is not None:
            np.random.seed(seed)

        # Set a random goal position within the valid range
        self.goal_position = np.array([
            np.random.uniform(-0.18700, 0.25300),
            np.random.uniform(-0.17050, 0.21950),
            np.random.uniform(0.16940, 0.28950)
        ], dtype=np.float32)

        # Update PID setpoints
        self.pid_x.setpoint = self.goal_position[0]
        self.pid_y.setpoint = self.goal_position[1]
        self.pid_z.setpoint = self.goal_position[2]

        # Reset the simulation environment
        observation = self.sim.reset(num_agents=1)

        # Extract pipette position and combine with goal position
        pipette_position = np.array(observation[f'robotId_{self.sim.robotIds[0]}']['pipette_position'], dtype=np.float32)
        observation = np.concatenate([pipette_position, self.goal_position], axis=0)

        self.steps = 0
        return observation, {}

    def step(self, action):
        # Extract current pipette position from the environment
        observation = self.sim.run([action])
        pipette_position = np.array(observation[f'robotId_{self.sim.robotIds[0]}']['pipette_position'], dtype=np.float32)

        # PID-controlled adjustment
        control_signal_x = self.pid_x.update(pipette_position[0])
        control_signal_y = self.pid_y.update(pipette_position[1])
        control_signal_z = self.pid_z.update(pipette_position[2])

        # Calculate new action based on PID output
        control_action = np.array([control_signal_x, control_signal_y, control_signal_z, 0.0], dtype=np.float32)

        # Execute the action in the simulation
        self.sim.run([control_action])

        # Update observation
        observation = np.concatenate([pipette_position, self.goal_position], axis=0)

        # Calculate reward based on distance to the goal
        reward = -np.linalg.norm(pipette_position - self.goal_position)

        # Check termination condition (10 mm accuracy requirement)
        distance = np.linalg.norm(pipette_position - self.goal_position)  # Distance in meters
        terminated = distance <= 0.001  # 10 mm accuracy

        if terminated:
            reward = 100  # Bonus for reaching the goal

        # Check truncation
        truncated = self.steps >= self.max_steps

        # Print debug information
        distance_mm = distance * 1000  # Convert distance to millimeters
        print(f"Step {self.steps}:")
        print(f"  Current Position: {pipette_position}")
        print(f"  Goal Position: {self.goal_position}")
        print(f"  Distance to Goal: {distance_mm:.2f} mm")

        self.steps += 1
        return observation, reward, terminated, truncated, {}

    def render(self):
        if self.render_enabled:
            self.sim.render()

    def close(self):
        self.sim.close()


# Testing Process
if __name__ == "__main__":
    env = OT2Env(render=True)
    observation, _ = env.reset()

    print(f"Goal Position: {env.goal_position}")

    for _ in range(10000):  # Simulate 50 steps
        action = env.action_space.sample()  # Example random action
        observation, reward, terminated, is_truncated, _ = env.step(action)

        if terminated or is_truncated:
            print("Goal Reached!" if terminated else "Simulation Truncated.")
            break

    env.close()
# Out:
# Goal Position: [-0.14755969  0.18229967  0.19934526]
# Step 0:
#   Current Position: [0.0735 0.0901 0.1195]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 252.47 mm
# Step 1:
#   Current Position: [0.0739 0.0904 0.1212]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 252.18 mm
# Step 2:
#   Current Position: [0.0735 0.0906 0.1222]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 251.45 mm
# Step 3:
#   Current Position: [0.0721 0.0921 0.1226]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 249.55 mm
# Step 4:
#   Current Position: [0.0698 0.0926 0.1245]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 246.77 mm
# Step 5:
#   Current Position: [0.0675 0.0931 0.125 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 244.41 mm
# Step 6:
#   Current Position: [0.0653 0.0936 0.1269]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 241.71 mm
# Step 7:
#   Current Position: [0.0625 0.0941 0.1289]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 238.47 mm
# Step 8:
#   Current Position: [0.0598 0.0957 0.1306]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 235.00 mm
# Step 9:
#   Current Position: [0.0561 0.0976 0.1449]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 227.19 mm
# Step 10:
#   Current Position: [0.0531 0.0985 0.1539]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 222.15 mm
# Step 11:
#   Current Position: [0.05   0.0994 0.1595]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 217.92 mm
# Step 12:
#   Current Position: [0.047  0.1003 0.1631]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 214.22 mm
# Step 13:
#   Current Position: [0.044  0.1012 0.1654]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 210.77 mm
# Step 14:
#   Current Position: [0.041  0.1021 0.1673]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 207.40 mm
# Step 15:
#   Current Position: [0.0379 0.103  0.1682]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 204.09 mm
# Step 16:
#   Current Position: [0.034  0.1043 0.1689]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 199.94 mm
# Step 17:
#   Current Position: [0.0294 0.1056 0.1709]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 194.95 mm
# Step 18:
#   Current Position: [0.0245 0.1069 0.1706]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 190.04 mm
# Step 19:
#   Current Position: [0.0203 0.1094 0.1699]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 185.36 mm
# Step 20:
#   Current Position: [0.0161 0.1108 0.1686]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 181.22 mm
# Step 21:
#   Current Position: [0.0112 0.1134 0.1698]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 175.57 mm
# Step 22:
#   Current Position: [0.0067 0.1149 0.1697]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 170.93 mm
# Step 23:
#   Current Position: [0.0022 0.1166 0.1711]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 165.96 mm
# Step 24:
#   Current Position: [-0.0022  0.1182  0.1733]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 160.99 mm
# Step 25:
#   Current Position: [-0.0067  0.1198  0.1732]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 156.30 mm
# Step 26:
#   Current Position: [-0.0112  0.1214  0.1747]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 151.36 mm
# Step 27:
#   Current Position: [-0.0156  0.1231  0.1747]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 146.72 mm
# Step 28:
#   Current Position: [-0.0201  0.1258  0.1739]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 141.72 mm
# Step 29:
#   Current Position: [-0.0246  0.1276  0.1725]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 137.23 mm
# Step 30:
#   Current Position: [-0.0291  0.1305  0.1726]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 132.03 mm
# Step 31:
#   Current Position: [-0.0337  0.1323  0.1749]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 126.73 mm
# Step 32:
#   Current Position: [-0.0382  0.1342  0.175 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 121.93 mm
# Step 33:
#   Current Position: [-0.0428  0.1372  0.1753]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 116.56 mm
# Step 34:
#   Current Position: [-0.0473  0.1402  0.1754]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 111.35 mm
# Step 35:
#   Current Position: [-0.0519  0.1421  0.1757]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 106.42 mm
# Step 36:
#   Current Position: [-0.0564  0.144   0.1758]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 101.64 mm
# Step 37:
#   Current Position: [-0.0609  0.1471  0.1755]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 96.53 mm
# Step 38:
#   Current Position: [-0.0655  0.149   0.1747]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 91.92 mm
# Step 39:
#   Current Position: [-0.07    0.151   0.1733]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 87.60 mm
# Step 40:
#   Current Position: [-0.0745  0.1529  0.1734]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 82.92 mm
# Step 41:
#   Current Position: [-0.0791  0.156   0.1736]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 77.73 mm
# Step 42:
#   Current Position: [-0.0836  0.1584  0.1755]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 72.32 mm
# Step 43:
#   Current Position: [-0.0881  0.1604  0.178 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 66.86 mm
# Step 44:
#   Current Position: [-0.0926  0.1635  0.1799]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 61.25 mm
# Step 45:
#   Current Position: [-0.0971  0.1666  0.1824]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 55.50 mm
# Step 46:
#   Current Position: [-0.1016  0.1697  0.1827]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 50.48 mm
# Step 47:
#   Current Position: [-0.1062  0.1728  0.1836]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 45.26 mm
# Step 48:
#   Current Position: [-0.1107  0.1755  0.1839]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 40.54 mm
# Step 49:
#   Current Position: [-0.1152  0.1785  0.1857]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 35.32 mm
# Step 50:
#   Current Position: [-0.1197  0.1804  0.186 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 30.95 mm
# Step 51:
#   Current Position: [-0.1242  0.1834  0.187 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 26.44 mm
# Step 52:
#   Current Position: [-0.1296  0.1853  0.1896]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 20.65 mm
# Step 53:
#   Current Position: [-0.1351  0.1882  0.19  ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 16.66 mm
# Step 54:
#   Current Position: [-0.1406  0.1912  0.1897]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 14.86 mm
# Step 55:
#   Current Position: [-0.1461  0.193   0.1911]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 13.59 mm
# Step 56:
#   Current Position: [-0.1515  0.1948  0.1914]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 15.33 mm
# Step 57:
#   Current Position: [-0.1569  0.1965  0.1933]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 18.04 mm
# Step 58:
#   Current Position: [-0.1622  0.1982  0.1946]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 22.13 mm
# Step 59:
#   Current Position: [-0.1683  0.201   0.1972]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 28.01 mm
# Step 60:
#   Current Position: [-0.1745  0.2026  0.1997]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 33.73 mm
# Step 61:
#   Current Position: [-0.1798  0.2042  0.1999]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 38.98 mm
# Step 62:
#   Current Position: [-0.1848  0.2058  0.1995]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 44.04 mm
# Step 63:
#   Current Position: [-0.1874  0.2083  0.2006]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 47.59 mm
# Step 64:
#   Current Position: [-0.1873  0.2098  0.2019]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 48.40 mm
# Step 65:
#   Current Position: [-0.1872  0.2123  0.2038]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 49.91 mm
# Step 66:
#   Current Position: [-0.1871  0.2138  0.204 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 50.77 mm
# Step 67:
#   Current Position: [-0.1866  0.2152  0.2035]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 51.22 mm
# Step 68:
#   Current Position: [-0.187   0.2167  0.2023]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 52.42 mm
# Step 69:
#   Current Position: [-0.1866  0.218   0.2005]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 52.91 mm
# Step 70:
#   Current Position: [-0.1863  0.2203  0.2003]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 54.27 mm
# Step 71:
#   Current Position: [-0.1871  0.22    0.2028]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 54.74 mm
# Step 72:
#   Current Position: [-0.1866  0.2198  0.2044]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 54.37 mm
# Step 73:
#   Current Position: [-0.1861  0.2197  0.206 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 54.11 mm
# Step 74:
#   Current Position: [-0.1865  0.2191  0.2085]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 54.35 mm
# Step 75:
#   Current Position: [-0.1873  0.2195  0.2086]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 55.22 mm
# Step 76:
#   Current Position: [-0.1868  0.2195  0.2103]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 55.17 mm
# Step 77:
#   Current Position: [-0.1862  0.2195  0.2116]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 55.02 mm
# Step 78:
#   Current Position: [-0.1856  0.2195  0.2139]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 55.16 mm
# Step 79:
#   Current Position: [-0.185  0.219  0.215]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 54.72 mm
# Step 80:
#   Current Position: [-0.1853  0.2195  0.215 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 55.26 mm
# Step 81:
#   Current Position: [-0.1865  0.2189  0.2166]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 56.16 mm
# Step 82:
#   Current Position: [-0.1873  0.2184  0.2188]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 57.11 mm
# Step 83:
#   Current Position: [-0.1872  0.2189  0.221 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 58.14 mm
# Step 84:
#   Current Position: [-0.1867  0.2196  0.2214]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 58.39 mm
# Step 85:
#   Current Position: [-0.1861  0.2195  0.2235]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 58.76 mm
# Step 86:
#   Current Position: [-0.1865  0.2199  0.2256]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 60.16 mm
# Step 87:
#   Current Position: [-0.1873  0.2192  0.2255]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 60.21 mm
# Step 88:
#   Current Position: [-0.1867  0.2185  0.2256]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 59.43 mm
# Step 89:
#   Current Position: [-0.1861  0.2178  0.2254]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 58.52 mm
# Step 90:
#   Current Position: [-0.1856  0.2171  0.2255]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 57.81 mm
# Step 91:
#   Current Position: [-0.1859  0.2175  0.2252]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 58.12 mm
# Step 92:
#   Current Position: [-0.1881  0.2192  0.2265]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 61.18 mm
# Step 93:
#   Current Position: [-0.1877  0.2197  0.2261]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 61.04 mm
# Step 94:
#   Current Position: [-0.187   0.2191  0.2251]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 59.78 mm
# Step 95:
#   Current Position: [-0.1862  0.2184  0.224 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 58.35 mm
# Step 96:
#   Current Position: [-0.1855  0.2178  0.2229]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 57.05 mm
# Step 97:
#   Current Position: [-0.185   0.2172  0.2234]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 56.55 mm
# Step 98:
#   Current Position: [-0.1847  0.2165  0.223 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 55.75 mm
# Step 99:
#   Current Position: [-0.1853  0.217   0.2219]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 56.01 mm
# Step 100:
#   Current Position: [-0.1869  0.2185  0.2208]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 57.61 mm
# Step 101:
#   Current Position: [-0.1877  0.2188  0.2197]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 57.95 mm
# Step 102:
#   Current Position: [-0.187   0.2192  0.2182]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 57.21 mm
# Step 103:
#   Current Position: [-0.1862  0.2194  0.2165]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 56.25 mm
# Step 104:
#   Current Position: [-0.1857  0.2197  0.2145]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 55.53 mm
# Step 105:
#   Current Position: [-0.1855  0.2191  0.2118]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 54.30 mm
# Step 106:
#   Current Position: [-0.1862  0.2184  0.2102]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 53.98 mm
# Step 107:
#   Current Position: [-0.1872  0.2189  0.2097]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 54.94 mm
# Step 108:
#   Current Position: [-0.1871  0.22    0.2085]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 55.39 mm
# Step 109:
#   Current Position: [-0.1866  0.2198  0.2089]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 54.97 mm
# Step 110:
#   Current Position: [-0.1861  0.2192  0.2085]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 54.14 mm
# Step 111:
#   Current Position: [-0.1865  0.2196  0.2096]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 54.89 mm
# Step 112:
#   Current Position: [-0.1873  0.2195  0.2096]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 55.39 mm
# Step 113:
#   Current Position: [-0.1867  0.219   0.2105]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 54.80 mm
# Step 114:
#   Current Position: [-0.1862  0.2184  0.2123]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 54.44 mm
# Step 115:
#   Current Position: [-0.1865  0.2189  0.214 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 55.41 mm
# Step 116:
#   Current Position: [-0.1873  0.2188  0.2135]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 55.78 mm
# Step 117:
#   Current Position: [-0.1872  0.2186  0.2122]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 55.27 mm
# Step 118:
#   Current Position: [-0.1871  0.2195  0.2115]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 55.63 mm
# Step 119:
#   Current Position: [-0.1871  0.2193  0.2132]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 55.90 mm
# Step 120:
#   Current Position: [-0.1866  0.219   0.2126]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 55.20 mm
# Step 121:
#   Current Position: [-0.1867  0.2198  0.2124]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 55.76 mm
# Step 122:
#   Current Position: [-0.1872  0.2191  0.2138]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 55.99 mm
# Step 123:
#   Current Position: [-0.1871  0.2185  0.2132]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 55.37 mm
# Step 124:
#   Current Position: [-0.1866  0.2181  0.2142]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 55.01 mm
# Step 125:
#   Current Position: [-0.1861  0.2177  0.2135]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 54.21 mm
# Step 126:
#   Current Position: [-0.1856  0.2181  0.2144]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 54.36 mm
# Step 127:
#   Current Position: [-0.186   0.2177  0.216 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 54.85 mm
# Step 128:
#   Current Position: [-0.1874  0.2172  0.2159]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 55.49 mm
# Step 129:
#   Current Position: [-0.1872  0.2177  0.2175]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 56.16 mm
# Step 130:
#   Current Position: [-0.1867  0.2183  0.219 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 56.69 mm
# Step 131:
#   Current Position: [-0.187   0.2178  0.2187]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 56.48 mm
# Step 132:
#   Current Position: [-0.1876  0.2182  0.2202]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 57.68 mm
# Step 133:
#   Current Position: [-0.1874  0.2179  0.2204]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 57.43 mm
# Step 134:
#   Current Position: [-0.1868  0.2172  0.2196]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 56.29 mm
# Step 135:
#   Current Position: [-0.1863  0.2176  0.2203]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 56.44 mm
# Step 136:
#   Current Position: [-0.1869  0.218   0.2195]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 56.82 mm
# Step 137:
#   Current Position: [-0.1877  0.2172  0.2179]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 56.33 mm
# Step 138:
#   Current Position: [-0.1874  0.2164  0.2179]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 55.63 mm
# Step 139:
#   Current Position: [-0.1868  0.2167  0.2193]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 55.87 mm
# Step 140:
#   Current Position: [-0.1871  0.217   0.2184]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 55.95 mm
# Step 141:
#   Current Position: [-0.1871  0.2162  0.2167]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 54.90 mm
# Step 142:
#   Current Position: [-0.187   0.2153  0.2167]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 54.27 mm
# Step 143:
#   Current Position: [-0.187   0.2146  0.2157]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 53.54 mm
# Step 144:
#   Current Position: [-0.1866  0.2148  0.2164]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 53.58 mm
# Step 145:
#   Current Position: [-0.187   0.2138  0.2154]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 52.97 mm
# Step 146:
#   Current Position: [-0.187   0.2139  0.216 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 53.21 mm
# Step 147:
#   Current Position: [-0.1867  0.213   0.2154]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 52.27 mm
# Step 148:
#   Current Position: [-0.1874  0.213   0.2166]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 53.17 mm
# Step 149:
#   Current Position: [-0.1872  0.2131  0.2178]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 53.48 mm
# Step 150:
#   Current Position: [-0.1867  0.212   0.2169]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 52.18 mm
# Step 151:
#   Current Position: [-0.187   0.212   0.2176]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 52.64 mm
# Step 152:
#   Current Position: [-0.1866  0.212   0.2186]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 52.70 mm
# Step 153:
#   Current Position: [-0.187   0.2109  0.2182]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 52.24 mm
# Step 154:
#   Current Position: [-0.187   0.2098  0.2171]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 51.25 mm
# Step 155:
#   Current Position: [-0.1865  0.2086  0.2155]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 49.69 mm
# Step 156:
#   Current Position: [-0.187   0.2074  0.2155]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 49.46 mm
# Step 157:
#   Current Position: [-0.1865  0.2061  0.2167]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 48.83 mm
# Step 158:
#   Current Position: [-0.1861  0.2049  0.2176]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 48.26 mm
# Step 159:
#   Current Position: [-0.1856  0.2048  0.2164]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 47.37 mm
# Step 160:
#   Current Position: [-0.1861  0.2036  0.2167]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 47.33 mm
# Step 161:
#   Current Position: [-0.187   0.2034  0.2164]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 47.87 mm
# Step 162:
#   Current Position: [-0.187   0.2033  0.2174]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 48.19 mm
# Step 163:
#   Current Position: [-0.187   0.202   0.2185]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 48.07 mm
# Step 164:
#   Current Position: [-0.1874  0.2019  0.2195]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 48.76 mm
# Step 165:
#   Current Position: [-0.1872  0.2017  0.2201]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 48.77 mm
# Step 166:
#   Current Position: [-0.1871  0.2004  0.2188]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 47.64 mm
# Step 167:
#   Current Position: [-0.1867  0.2002  0.2168]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 46.44 mm
# Step 168:
#   Current Position: [-0.1863  0.1988  0.2163]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 45.39 mm
# Step 169:
#   Current Position: [-0.1859  0.1986  0.215 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 44.51 mm
# Step 170:
#   Current Position: [-0.1864  0.1972  0.2152]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 44.52 mm
# Step 171:
#   Current Position: [-0.1873  0.1959  0.2139]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 44.45 mm
# Step 172:
#   Current Position: [-0.1872  0.1945  0.2135]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 43.82 mm
# Step 173:
#   Current Position: [-0.1867  0.1943  0.2144]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 43.62 mm
# Step 174:
#   Current Position: [-0.1864  0.194   0.2131]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 42.83 mm
# Step 175:
#   Current Position: [-0.1871  0.1927  0.2112]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 42.57 mm
# Step 176:
#   Current Position: [-0.1866  0.1924  0.2108]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 41.92 mm
# Step 177:
#   Current Position: [-0.1861  0.1911  0.2094]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 40.79 mm
# Step 178:
#   Current Position: [-0.1865  0.1897  0.2092]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 40.84 mm
# Step 179:
#   Current Position: [-0.1873  0.1894  0.2101]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 41.78 mm
# Step 180:
#   Current Position: [-0.1867  0.1881  0.2105]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 41.11 mm
# Step 181:
#   Current Position: [-0.1861  0.1867  0.2091]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 40.00 mm
# Step 182:
#   Current Position: [-0.1865  0.1858  0.207 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 39.84 mm
# Step 183:
#   Current Position: [-0.1872  0.1845  0.2042]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 40.00 mm
# Step 184:
#   Current Position: [-0.1867  0.1831  0.2029]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 39.31 mm
# Step 185:
#   Current Position: [-0.1861  0.1818  0.2018]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 38.62 mm
# Step 186:
#   Current Position: [-0.1865  0.1805  0.2002]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 38.99 mm
# Step 187:
#   Current Position: [-0.1872  0.1791  0.198 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 39.79 mm
# Step 188:
#   Current Position: [-0.1871  0.1779  0.1976]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 39.82 mm
# Step 189:
#   Current Position: [-0.1871  0.1778  0.1963]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 39.91 mm
# Step 190:
#   Current Position: [-0.1866  0.1776  0.1965]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 39.42 mm
# Step 191:
#   Current Position: [-0.1863  0.1775  0.1952]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 39.26 mm
# Step 192:
#   Current Position: [-0.1871  0.1764  0.1955]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 40.16 mm
# Step 193:
#   Current Position: [-0.187   0.1757  0.1959]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 40.14 mm
# Step 194:
#   Current Position: [-0.187   0.1756  0.1968]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 40.09 mm
# Step 195:
#   Current Position: [-0.1866  0.1744  0.1978]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 39.86 mm
# Step 196:
#   Current Position: [-0.187   0.1742  0.1987]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 40.27 mm
# Step 197:
#   Current Position: [-0.1865  0.1742  0.1974]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 39.82 mm
# Step 198:
#   Current Position: [-0.1861  0.1741  0.1976]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 39.44 mm
# Step 199:
#   Current Position: [-0.1865  0.174   0.1963]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 39.93 mm
# Step 200:
#   Current Position: [-0.187   0.1731  0.1943]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 40.81 mm
# Step 201:
#   Current Position: [-0.187   0.1726  0.1939]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 40.98 mm
# Step 202:
#   Current Position: [-0.1865  0.1714  0.1927]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 40.98 mm
# Step 203:
#   Current Position: [-0.1861  0.1709  0.193 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 40.69 mm
# Step 204:
#   Current Position: [-0.1862  0.1698  0.192 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 41.27 mm
# Step 205:
#   Current Position: [-0.1875  0.1687  0.1906]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 43.09 mm
# Step 206:
#   Current Position: [-0.1873  0.1676  0.1885]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 43.74 mm
# Step 207:
#   Current Position: [-0.1867  0.1665  0.1881]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 43.68 mm
# Step 208:
#   Current Position: [-0.1871  0.1654  0.1869]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 44.77 mm
# Step 209:
#   Current Position: [-0.1866  0.1643  0.185 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 45.32 mm
# Step 210:
#   Current Position: [-0.1861  0.1632  0.1825]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 46.19 mm
# Step 211:
#   Current Position: [-0.1865  0.1621  0.1802]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 47.86 mm
# Step 212:
#   Current Position: [-0.1875  0.1621  0.1805]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 48.56 mm
# Step 213:
#   Current Position: [-0.1874  0.1623  0.1794]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 48.84 mm
# Step 214:
#   Current Position: [-0.1868  0.1625  0.1777]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 48.99 mm
# Step 215:
#   Current Position: [-0.1871  0.1616  0.1753]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 50.70 mm
# Step 216:
#   Current Position: [-0.187   0.1619  0.1744]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 50.93 mm
# Step 217:
#   Current Position: [-0.187   0.1617  0.1735]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 51.46 mm
# Step 218:
#   Current Position: [-0.1866  0.1609  0.174 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 51.23 mm
# Step 219:
#   Current Position: [-0.1861  0.1601  0.1737]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 51.34 mm
# Step 220:
#   Current Position: [-0.1865  0.1592  0.1751]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 51.36 mm
# Step 221:
#   Current Position: [-0.1863  0.1584  0.1743]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 51.95 mm
# Step 222:
#   Current Position: [-0.187   0.1586  0.175 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 52.06 mm
# Step 223:
#   Current Position: [-0.1866  0.1579  0.1745]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 52.31 mm
# Step 224:
#   Current Position: [-0.187   0.1583  0.1736]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 52.86 mm
# Step 225:
#   Current Position: [-0.187   0.1587  0.172 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 53.48 mm
# Step 226:
#   Current Position: [-0.187   0.1592  0.1703]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 54.15 mm
# Step 227:
#   Current Position: [-0.1865  0.1597  0.171 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 53.20 mm
# Step 228:
#   Current Position: [-0.1864  0.1602  0.1726]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 52.08 mm
# Step 229:
#   Current Position: [-0.1868  0.1601  0.1742]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 51.62 mm
# Step 230:
#   Current Position: [-0.1863  0.1596  0.1736]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 51.76 mm
# Step 231:
#   Current Position: [-0.1867  0.1598  0.1723]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 52.63 mm
# Step 232:
#   Current Position: [-0.1862  0.1598  0.1725]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 52.15 mm
# Step 233:
#   Current Position: [-0.1865  0.1604  0.1743]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 51.22 mm
# Step 234:
#   Current Position: [-0.1859  0.1599  0.1758]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 50.26 mm
# Step 235:
#   Current Position: [-0.1853  0.1594  0.177 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 49.48 mm
# Step 236:
#   Current Position: [-0.1848  0.16    0.1765]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 49.05 mm
# Step 237:
#   Current Position: [-0.185   0.1595  0.1752]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 50.05 mm
# Step 238:
#   Current Position: [-0.1852  0.1602  0.1756]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 49.69 mm
# Step 239:
#   Current Position: [-0.1854  0.1609  0.176 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 49.34 mm
# Step 240:
#   Current Position: [-0.1847  0.1616  0.1756]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 48.70 mm
# Step 241:
#   Current Position: [-0.1848  0.1612  0.1767]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 48.42 mm
# Step 242:
#   Current Position: [-0.1845  0.1615  0.1785]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 47.24 mm
# Step 243:
#   Current Position: [-0.1845  0.1623  0.1781]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 47.07 mm
# Step 244:
#   Current Position: [-0.1836  0.163   0.177 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 46.59 mm
# Step 245:
#   Current Position: [-0.1836  0.1638  0.1775]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 46.03 mm
# Step 246:
#   Current Position: [-0.1827  0.1635  0.1794]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 44.57 mm
# Step 247:
#   Current Position: [-0.1817  0.1643  0.1791]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 43.58 mm
# Step 248:
#   Current Position: [-0.1807  0.1639  0.1803]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 42.42 mm
# Step 249:
#   Current Position: [-0.1806  0.1648  0.18  ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 42.10 mm
# Step 250:
#   Current Position: [-0.18    0.1645  0.1813]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 41.17 mm
# Step 251:
#   Current Position: [-0.1798  0.1644  0.1819]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 40.79 mm
# Step 252:
#   Current Position: [-0.1797  0.1653  0.1816]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 40.46 mm
# Step 253:
#   Current Position: [-0.1795  0.165   0.1829]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 39.87 mm
# Step 254:
#   Current Position: [-0.1784  0.1659  0.184 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 38.15 mm
# Step 255:
#   Current Position: [-0.1773  0.1657  0.1837]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 37.48 mm
# Step 256:
#   Current Position: [-0.1761  0.1655  0.1851]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 36.05 mm
# Step 257:
#   Current Position: [-0.1749  0.1652  0.1861]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 34.86 mm
# Step 258:
#   Current Position: [-0.1737  0.1661  0.1858]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 33.60 mm
# Step 259:
#   Current Position: [-0.1734  0.166   0.1855]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 33.54 mm
# Step 260:
#   Current Position: [-0.1721  0.1658  0.1874]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 31.89 mm
# Step 261:
#   Current Position: [-0.1718  0.1656  0.1874]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 31.77 mm
# Step 262:
#   Current Position: [-0.1715  0.1655  0.1891]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 30.99 mm
# Step 263:
#   Current Position: [-0.1702  0.1664  0.1912]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 28.84 mm
# Step 264:
#   Current Position: [-0.1689  0.1663  0.1919]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 27.69 mm
# Step 265:
#   Current Position: [-0.1685  0.1673  0.1917]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 26.87 mm
# Step 266:
#   Current Position: [-0.1672  0.1684  0.1931]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 24.86 mm
# Step 267:
#   Current Position: [-0.1668  0.1683  0.1951]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 24.17 mm
# Step 268:
#   Current Position: [-0.1664  0.1693  0.1971]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 23.00 mm
# Step 269:
#   Current Position: [-0.1651  0.1703  0.1972]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 21.36 mm
# Step 270:
#   Current Position: [-0.1647  0.1703  0.198 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 20.97 mm
# Step 271:
#   Current Position: [-0.1633  0.1702  0.1986]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 19.87 mm
# Step 272:
#   Current Position: [-0.1619  0.1701  0.2006]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 18.87 mm
# Step 273:
#   Current Position: [-0.1615  0.1701  0.2003]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 18.55 mm
# Step 274:
#   Current Position: [-0.1611  0.1711  0.2011]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 17.66 mm
# Step 275:
#   Current Position: [-0.1597  0.1722  0.2008]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 15.86 mm
# Step 276:
#   Current Position: [-0.1583  0.1722  0.2   ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 14.76 mm
# Step 277:
#   Current Position: [-0.1569  0.1733  0.2009]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 13.06 mm
# Step 278:
#   Current Position: [-0.1565  0.1744  0.2029]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 12.45 mm
# Step 279:
#   Current Position: [-0.1551  0.1744  0.2031]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 11.55 mm
# Step 280:
#   Current Position: [-0.1537  0.1755  0.205 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 10.77 mm
# Step 281:
#   Current Position: [-0.1526  0.1766  0.2052]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 9.60 mm
# Step 282:
#   Current Position: [-0.1522  0.1766  0.2071]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 10.68 mm
# Step 283:
#   Current Position: [-0.1508  0.1777  0.2068]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 9.34 mm
# Step 284:
#   Current Position: [-0.1495  0.1788  0.2063]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 8.02 mm
# Step 285:
#   Current Position: [-0.1481  0.1787  0.2056]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 7.24 mm
# Step 286:
#   Current Position: [-0.1468  0.1798  0.2065]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 7.62 mm
# Step 287:
#   Current Position: [-0.1463  0.1809  0.2084]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 9.25 mm
# Step 288:
#   Current Position: [-0.145   0.182   0.2097]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 10.67 mm
# Step 289:
#   Current Position: [-0.1437  0.1831  0.2115]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 12.78 mm
# Step 290:
#   Current Position: [-0.1433  0.1842  0.2134]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 14.81 mm
# Step 291:
#   Current Position: [-0.1429  0.1853  0.2131]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 14.83 mm
# Step 292:
#   Current Position: [-0.1426  0.1852  0.2147]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 16.39 mm
# Step 293:
#   Current Position: [-0.1413  0.1863  0.2165]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 18.69 mm
# Step 294:
#   Current Position: [-0.1401  0.1865  0.2182]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 20.71 mm
# Step 295:
#   Current Position: [-0.1388  0.1875  0.2195]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 22.58 mm
# Step 296:
#   Current Position: [-0.1375  0.1874  0.2211]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 24.50 mm
# Step 297:
#   Current Position: [-0.1372  0.1884  0.2228]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 26.36 mm
# Step 298:
#   Current Position: [-0.1369  0.1894  0.2244]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 28.14 mm
# Step 299:
#   Current Position: [-0.1358  0.1892  0.2237]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 27.91 mm
# Step 300:
#   Current Position: [-0.1346  0.1891  0.2233]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 28.07 mm
# Step 301:
#   Current Position: [-0.1343  0.1896  0.2248]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 29.62 mm
# Step 302:
#   Current Position: [-0.1332  0.1894  0.2263]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 31.36 mm
# Step 303:
#   Current Position: [-0.133   0.1893  0.2255]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 30.74 mm
# Step 304:
#   Current Position: [-0.1329  0.1893  0.2241]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 29.61 mm
# Step 305:
#   Current Position: [-0.1318  0.1902  0.2219]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 28.63 mm
# Step 306:
#   Current Position: [-0.131   0.19    0.2213]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 28.56 mm
# Step 307:
#   Current Position: [-0.13    0.1906  0.2227]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 30.38 mm
# Step 308:
#   Current Position: [-0.129   0.1915  0.2218]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 30.55 mm
# Step 309:
#   Current Position: [-0.1288  0.1913  0.2203]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 29.53 mm
# Step 310:
#   Current Position: [-0.1288  0.1911  0.2203]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 29.47 mm
# Step 311:
#   Current Position: [-0.1278  0.1909  0.2194]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 29.44 mm
# Step 312:
#   Current Position: [-0.1278  0.1917  0.2201]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 30.16 mm
# Step 313:
#   Current Position: [-0.1269  0.1926  0.2214]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 31.93 mm
# Step 314:
#   Current Position: [-0.1269  0.1925  0.2219]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 32.24 mm
# Step 315:
#   Current Position: [-0.1261  0.1934  0.2231]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 33.88 mm
# Step 316:
#   Current Position: [-0.1256  0.1931  0.2224]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 33.62 mm
# Step 317:
#   Current Position: [-0.1257  0.1928  0.2212]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 32.65 mm
# Step 318:
#   Current Position: [-0.1258  0.1925  0.2194]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 31.30 mm
# Step 319:
#   Current Position: [-0.126   0.1933  0.2191]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 31.24 mm
# Step 320:
#   Current Position: [-0.1261  0.1937  0.22  ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 31.89 mm
# Step 321:
#   Current Position: [-0.1263  0.1934  0.2212]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 32.45 mm
# Step 322:
#   Current Position: [-0.1256  0.1931  0.2201]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 32.09 mm
# Step 323:
#   Current Position: [-0.1257  0.1938  0.2206]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 32.59 mm
# Step 324:
#   Current Position: [-0.1251  0.1941  0.2204]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 32.97 mm
# Step 325:
#   Current Position: [-0.1244  0.1937  0.2215]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 34.02 mm
# Step 326:
#   Current Position: [-0.1246  0.1933  0.2203]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 32.97 mm
# Step 327:
#   Current Position: [-0.1249  0.1941  0.2193]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 32.42 mm
# Step 328:
#   Current Position: [-0.1243  0.1948  0.2181]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 32.39 mm
# Step 329:
#   Current Position: [-0.1237  0.1955  0.2184]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 33.27 mm
# Step 330:
#   Current Position: [-0.1231  0.1956  0.2172]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 33.08 mm
# Step 331:
#   Current Position: [-0.1234  0.1951  0.2171]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 32.60 mm
# Step 332:
#   Current Position: [-0.1238  0.1956  0.2166]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 32.24 mm
# Step 333:
#   Current Position: [-0.1233  0.1962  0.2176]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 33.39 mm
# Step 334:
#   Current Position: [-0.123   0.1958  0.2176]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 33.45 mm
# Step 335:
#   Current Position: [-0.1234  0.1953  0.2163]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 32.25 mm
# Step 336:
#   Current Position: [-0.1239  0.1949  0.2166]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 31.88 mm
# Step 337:
#   Current Position: [-0.1239  0.1943  0.2176]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 32.20 mm
# Step 338:
#   Current Position: [-0.1235  0.1938  0.2185]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 32.83 mm
# Step 339:
#   Current Position: [-0.1231  0.1944  0.2186]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 33.40 mm
# Step 340:
#   Current Position: [-0.1227  0.195   0.2172]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 33.14 mm
# Step 341:
#   Current Position: [-0.1223  0.1945  0.216 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 32.62 mm
# Step 342:
#   Current Position: [-0.1229  0.195   0.2169]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 32.83 mm
# Step 343:
#   Current Position: [-0.1235  0.1956  0.2162]
# ...
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 7.95 mm
# Step 1322:
#   Current Position: [-0.1495  0.1888  0.1958]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 7.65 mm
# Step 1323:
#   Current Position: [-0.1499  0.1882  0.1947]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 7.87 mm
# Step 1324:
#   Current Position: [-0.1504  0.1876  0.1953]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 7.25 mm
# Step 1325:
#   Current Position: [-0.1504  0.1881  0.1965]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 7.06 mm
# Step 1326:
#   Current Position: [-0.1509  0.1875  0.1963]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 6.89 mm
# Step 1327:
#   Current Position: [-0.1505  0.1868  0.1975]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 5.68 mm
# Step 1328:
#   Current Position: [-0.15    0.1873  0.1987]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 5.60 mm
# Step 1329:
#   Current Position: [-0.1496  0.1878  0.2   ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 5.90 mm
# Step 1330:
#   Current Position: [-0.1501  0.1883  0.1989]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 6.53 mm
# Step 1331:
#   Current Position: [-0.1506  0.1877  0.1971]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 6.59 mm
# Step 1332:
#   Current Position: [-0.1502  0.1881  0.1956]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 7.39 mm
# Step 1333:
#   Current Position: [-0.1507  0.1886  0.1967]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 7.52 mm
# Step 1334:
#   Current Position: [-0.1503  0.1891  0.1956]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 8.23 mm
# Step 1335:
#   Current Position: [-0.1499  0.1884  0.1952]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 7.74 mm
# Step 1336:
#   Current Position: [-0.1503  0.1889  0.1958]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 7.98 mm
# Step 1337:
#   Current Position: [-0.1499  0.1888  0.1948]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 8.27 mm
# Step 1338:
#   Current Position: [-0.1502  0.1892  0.193 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 9.74 mm
# Step 1339:
#   Current Position: [-0.1502  0.1886  0.1929]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 9.39 mm
# Step 1340:
#   Current Position: [-0.1507  0.1879  0.1926]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 9.31 mm
# Step 1341:
#   Current Position: [-0.1508  0.1882  0.1923]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 9.74 mm
# Step 1342:
#   Current Position: [-0.1504  0.1875  0.1936]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 8.25 mm
# Step 1343:
#   Current Position: [-0.1499  0.1868  0.1927]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 8.36 mm
# Step 1344:
#   Current Position: [-0.1495  0.1872  0.191 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 9.87 mm
# Step 1345:
#   Current Position: [-0.149   0.1865  0.1909]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 9.54 mm
# Step 1346:
#   Current Position: [-0.1495  0.1858  0.1913]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 8.99 mm
# Step 1347:
#   Current Position: [-0.1491  0.1851  0.1919]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 8.10 mm
# Step 1348:
#   Current Position: [-0.1486  0.1844  0.191 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 8.67 mm
# Step 1349:
#   Current Position: [-0.1482  0.1847  0.1894]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 10.25 mm
# Step 1350:
#   Current Position: [-0.1486  0.1851  0.1892]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 10.58 mm
# Step 1351:
#   Current Position: [-0.1491  0.1855  0.1906]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 9.44 mm
# Step 1352:
#   Current Position: [-0.1487  0.1859  0.192 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 8.26 mm
# Step 1353:
#   Current Position: [-0.1491  0.1864  0.1924]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 8.21 mm
# Step 1354:
#   Current Position: [-0.1487  0.1856  0.1938]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 6.55 mm
# Step 1355:
#   Current Position: [-0.1482  0.186   0.1951]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 5.67 mm
# Step 1356:
#   Current Position: [-0.1478  0.1853  0.1942]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 5.96 mm
# Step 1357:
#   Current Position: [-0.1476  0.1857  0.1927]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 7.46 mm
# Step 1358:
#   Current Position: [-0.1472  0.1861  0.1928]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 7.58 mm
# Step 1359:
#   Current Position: [-0.1477  0.1854  0.1927]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 7.33 mm
# Step 1360:
#   Current Position: [-0.1482  0.1846  0.1925]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 7.25 mm
# Step 1361:
#   Current Position: [-0.1478  0.185   0.1939]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 6.08 mm
# Step 1362:
#   Current Position: [-0.1482  0.1854  0.1931]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 7.00 mm
# Step 1363:
#   Current Position: [-0.1487  0.1852  0.1938]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 6.36 mm
# Step 1364:
#   Current Position: [-0.1492  0.1845  0.1952]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 4.97 mm
# Step 1365:
#   Current Position: [-0.1487  0.1848  0.1967]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 3.81 mm
# Step 1366:
#   Current Position: [-0.1492  0.1845  0.1958]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 4.48 mm
# Step 1367:
#   Current Position: [-0.1487  0.1838  0.1945]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 5.20 mm
# Step 1368:
#   Current Position: [-0.1483  0.1842  0.1927]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 6.95 mm
# Step 1369:
#   Current Position: [-0.1488  0.1845  0.1925]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 7.30 mm
# Step 1370:
#   Current Position: [-0.1483  0.1849  0.1917]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 8.11 mm
# Step 1371:
#   Current Position: [-0.1488  0.1842  0.1902]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 9.42 mm
# Step 1372:
#   Current Position: [-0.1492  0.184   0.1903]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 9.35 mm
# Step 1373:
#   Current Position: [-0.1487  0.1844  0.1916]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 8.11 mm
# Step 1374:
#   Current Position: [-0.1483  0.1836  0.1923]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 7.20 mm
# Step 1375:
#   Current Position: [-0.1487  0.1829  0.1915]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 7.95 mm
# Step 1376:
#   Current Position: [-0.1492  0.1821  0.1924]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 7.14 mm
# Step 1377:
#   Current Position: [-0.1497  0.1825  0.1939]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 5.85 mm
# Step 1378:
#   Current Position: [-0.1501  0.1818  0.1954]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 4.72 mm
# Step 1379:
#   Current Position: [-0.1506  0.1821  0.1946]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 5.64 mm
# Step 1380:
#   Current Position: [-0.151   0.1825  0.1954]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 5.24 mm
# Step 1381:
#   Current Position: [-0.1506  0.1818  0.1946]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 5.66 mm
# Step 1382:
#   Current Position: [-0.1501  0.1811  0.1954]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 4.84 mm
# Step 1383:
#   Current Position: [-0.1505  0.1814  0.1969]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 3.93 mm
# Step 1384:
#   Current Position: [-0.1508  0.1818  0.1978]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 3.62 mm
# Step 1385:
#   Current Position: [-0.1508  0.1811  0.197 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 4.18 mm
# Step 1386:
#   Current Position: [-0.1512  0.1815  0.1978]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 4.03 mm
# Step 1387:
#   Current Position: [-0.1516  0.1819  0.1988]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 4.10 mm
# Step 1388:
#   Current Position: [-0.1511  0.1823  0.2   ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 3.60 mm
# Step 1389:
#   Current Position: [-0.1515  0.1826  0.2014]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 4.45 mm
# Step 1390:
#   Current Position: [-0.1519  0.183   0.2029]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 5.65 mm
# Step 1391:
#   Current Position: [-0.1514  0.1834  0.2021]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 4.85 mm
# Step 1392:
#   Current Position: [-0.1518  0.1838  0.201 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 4.79 mm
# Step 1393:
#   Current Position: [-0.1521  0.1842  0.1996]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 4.93 mm
# Step 1394:
#   Current Position: [-0.1516  0.1835  0.1976]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 4.56 mm
# Step 1395:
#   Current Position: [-0.152   0.1827  0.1962]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 5.46 mm
# Step 1396:
#   Current Position: [-0.1524  0.1831  0.1976]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 5.21 mm
# Step 1397:
#   Current Position: [-0.1527  0.1834  0.198 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 5.43 mm
# Step 1398:
#   Current Position: [-0.1521  0.1838  0.1995]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 4.78 mm
# Step 1399:
#   Current Position: [-0.1525  0.1842  0.1987]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 5.33 mm
# Step 1400:
#   Current Position: [-0.1519  0.1834  0.1972]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 4.96 mm
# Step 1401:
#   Current Position: [-0.1523  0.1838  0.195 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 6.60 mm
# Step 1402:
#   Current Position: [-0.1517  0.1842  0.1933]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 7.57 mm
# Step 1403:
#   Current Position: [-0.1521  0.1834  0.1921]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 8.62 mm
# Step 1404:
#   Current Position: [-0.1515  0.1831  0.1904]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 9.81 mm
# Step 1405:
#   Current Position: [-0.1509  0.1834  0.1897]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 10.27 mm
# Step 1406:
#   Current Position: [-0.1503  0.1838  0.1913]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 8.63 mm
# Step 1407:
#   Current Position: [-0.1507  0.1842  0.1929]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 7.42 mm
# Step 1408:
#   Current Position: [-0.1501  0.1845  0.193 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 7.18 mm
# Step 1409:
#   Current Position: [-0.1497  0.1838  0.1924]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 7.42 mm
# Step 1410:
#   Current Position: [-0.1492  0.1831  0.191 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 8.54 mm
# Step 1411:
#   Current Position: [-0.1486  0.1823  0.1905]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 8.91 mm
# Step 1412:
#   Current Position: [-0.1489  0.1815  0.1921]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 7.41 mm
# Step 1413:
#   Current Position: [-0.1493  0.1819  0.1915]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 8.05 mm
# Step 1414:
#   Current Position: [-0.1496  0.1822  0.1924]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 7.24 mm
# Step 1415:
#   Current Position: [-0.15    0.1815  0.1934]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 6.48 mm
# Step 1416:
#   Current Position: [-0.1503  0.1819  0.1928]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 7.11 mm
# Step 1417:
#   Current Position: [-0.1502  0.1822  0.1915]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 8.28 mm
# Step 1418:
#   Current Position: [-0.1496  0.1815  0.1916]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 8.05 mm
# Step 1419:
#   Current Position: [-0.1499  0.1818  0.1933]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 6.50 mm
# Step 1420:
#   Current Position: [-0.1502  0.1822  0.1949]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 5.17 mm
# Step 1421:
#   Current Position: [-0.1505  0.1821  0.1962]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 4.31 mm
# Step 1422:
#   Current Position: [-0.1509  0.1825  0.1956]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 5.02 mm
# Step 1423:
#   Current Position: [-0.1503  0.1829  0.1965]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 4.00 mm
# Step 1424:
#   Current Position: [-0.1506  0.1825  0.197 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 3.84 mm
# Step 1425:
#   Current Position: [-0.15    0.1819  0.1986]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 2.58 mm
# Step 1426:
#   Current Position: [-0.1494  0.1823  0.2002]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 2.03 mm
# Step 1427:
#   Current Position: [-0.1488  0.1815  0.201 ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 2.22 mm
# Step 1428:
#   Current Position: [-0.1491  0.1819  0.2026]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 3.62 mm
# Step 1429:
#   Current Position: [-0.1494  0.1822  0.2019]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 3.15 mm
# Step 1430:
#   Current Position: [-0.1488  0.1823  0.2005]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 1.69 mm
# Step 1431:
#   Current Position: [-0.1482  0.1827  0.2007]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 1.55 mm
# Step 1432:
#   Current Position: [-0.148   0.1819  0.2   ]
#   Goal Position: [-0.14755969  0.18229967  0.19934526]
#   Distance to Goal: 0.88 mm
# Goal Reached!
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
